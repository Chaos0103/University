# %%
pip install finterstellar
# Out:
# Collecting finterstellar
#   Downloading finterstellar-0.1.19-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (1.21.5)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (2.23.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (1.3.5)
# Collecting pandas-datareader>=0.10.0
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 5.1 MB/s
# Requirement already satisfied: lxml>=4.2.6 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (4.2.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->finterstellar) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->finterstellar) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->finterstellar) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (2021.10.8)
# Installing collected packages: pandas-datareader, finterstellar
#   Attempting uninstall: pandas-datareader
#     Found existing installation: pandas-datareader 0.9.0
#     Uninstalling pandas-datareader-0.9.0:
#       Successfully uninstalled pandas-datareader-0.9.0
# Successfully installed finterstellar-0.1.19 pandas-datareader-0.10.0

# %%
import finterstellar as fs

# %%
t = '2020Q3'
data = fs.fn_consolidated(otp=16482659151081211164, term=t, vol=0)
data['PER'] = data['Price_M3'] / data['EPS']
data['PBR'] = data['Price_M3'] / (data['Shareholders Equity'] / data['Shares'])
s1 = fs.fn_filter(data, by='PER', floor=1, cap=10, n=20, asc=True)
s2 = fs.fn_filter(data, by='PBR', floor=.1, cap=1, n=20, asc=True)
# Out:
# 2020Q3...OK

# %%
print(s1)
# Out:
#              PER
# symbol
# VHC     1.250620
# UIS     1.348869
# JOB     1.538462
# MX      1.575758
# SND     1.577982
# VTOL    1.613744
# TNK     1.658133
# LIVE    1.919629
# BMA     1.941397
# LODE    1.962264
# CTO     2.126072
# FRO     2.245487
# TROX    2.270186
# DHT     2.324444
# BIG     2.329354
# DX      2.354497
# GGAL    2.355795
# TPHS    2.358491
# NRG     2.382614
# FVE     2.387543

# %%
print(s2)
# Out:
#              PBR
# symbol
# REI     0.103666
# ACOR    0.104986
# TNP     0.105140
# GECC    0.105790
# LTRPA   0.115385
# BORR    0.120192
# RIG     0.124788
# GNW     0.125471
# GLOP    0.136601
# GURE    0.149526
# SMHI    0.155095
# CDEV    0.155154
# FET     0.155406
# GASS    0.157510
# IRS     0.166423
# BBGI    0.168959
# NMM     0.174185
# TCOM    0.174534
# BHF     0.183101
# WPG     0.190015

# %%
fs.combine_signal(s1, s2, how='and')
# Out:
# Empty DataFrame
# Columns: [PER, PBR]
# Index: []

# %%
fs.combine_signal(s1, s2, how='or')
# Out:
#              PER       PBR
# symbol
# ACOR         NaN  0.104986
# BBGI         NaN  0.168959
# BHF          NaN  0.183101
# BIG     2.329354       NaN
# BMA     1.941397       NaN
# BORR         NaN  0.120192
# CDEV         NaN  0.155154
# CTO     2.126072       NaN
# DHT     2.324444       NaN
# DX      2.354497       NaN
# FET          NaN  0.155406
# FRO     2.245487       NaN
# FVE     2.387543       NaN
# GASS         NaN  0.157510
# GECC         NaN  0.105790
# GGAL    2.355795       NaN
# GLOP         NaN  0.136601
# GNW          NaN  0.125471
# GURE         NaN  0.149526
# IRS          NaN  0.166423
# JOB     1.538462       NaN
# LIVE    1.919629       NaN
# LODE    1.962264       NaN
# LTRPA        NaN  0.115385
# MX      1.575758       NaN
# NMM          NaN  0.174185
# NRG     2.382614       NaN
# REI          NaN  0.103666
# RIG          NaN  0.124788
# SMHI         NaN  0.155095
# SND     1.577982       NaN
# TCOM         NaN  0.174534
# TNK     1.658133       NaN
# TNP          NaN  0.105140
# TPHS    2.358491       NaN
# TROX    2.270186       NaN
# UIS     1.348869       NaN
# VHC     1.250620       NaN
# VTOL    1.613744       NaN
# WPG          NaN  0.190015

# %%
s1 = fs.fn_score(data, by='PER', method='absolute', floor=1, cap=10, asc=True)
s2 = fs.fn_score(data, by='PBR', method='absolute', floor=.1, cap=1, asc=True)

# %%
print(s1)
# Out:
#              PER  Score
# symbol
# VHC     1.250620   97.2
# UIS     1.348869   96.1
# JOB     1.538462   94.0
# MX      1.575758   93.6
# SND     1.577982   93.6
# ...          ...    ...
# CZWI    9.900000    1.1
# LCNB    9.925676    0.8
# RDN     9.926471    0.8
# FISI    9.955752    0.5
# EBTC    9.980469    0.2
#
# [294 rows x 2 columns]

# %%
print(s2)
# Out:
#              PBR  Score
# symbol
# REI     0.103666   99.6
# ACOR    0.104986   99.4
# TNP     0.105140   99.4
# GECC    0.105790   99.4
# LTRPA   0.115385   98.3
# ...          ...    ...
# STCN    0.997557    0.3
# SITC    0.997706    0.3
# FCF     0.998493    0.2
# TEVA    0.998527    0.2
# CRS     0.999287    0.1
#
# [811 rows x 2 columns]

# %%
fs.combine_score(s1, s2, n=10)
# Out:
#         Score  Score_    Sum
# symbol
# SND     46.80   42.40  89.20
# GECC    38.75   49.70  88.45
# TNK     46.35   37.65  84.00
# STNG    36.90   39.60  76.50
# PVL     37.10   37.20  74.30
# LIVE    44.90   28.60  73.50
# AEL     39.25   32.50  71.75
# JOB     47.00   24.70  71.70
# TNP     20.70   49.70  70.40
# BMA     44.75   25.40  70.15

# %%
s1 = fs.fn_score(data, by='PER', method='relative', floor=1, cap=10, asc=True)
s2 = fs.fn_score(data, by='PBR', method='relative', floor=.1, cap=1, asc=True)

# %%
print(s1)
# Out:
#              PER  Score
# symbol
# VHC     1.250620  100.0
# UIS     1.348869   99.7
# JOB     1.538462   99.3
# MX      1.575758   99.0
# SND     1.577982   98.6
# ...          ...    ...
# CZWI    9.900000    1.7
# LCNB    9.925676    1.4
# RDN     9.926471    1.0
# FISI    9.955752    0.7
# EBTC    9.980469    0.3
#
# [294 rows x 2 columns]

# %%
print(s2)
# Out:
#              PBR  Score
# symbol
# REI     0.103666  100.0
# ACOR    0.104986   99.9
# TNP     0.105140   99.8
# GECC    0.105790   99.6
# LTRPA   0.115385   99.5
# ...          ...    ...
# STCN    0.997557    0.6
# SITC    0.997706    0.5
# FCF     0.998493    0.4
# TEVA    0.998527    0.2
# CRS     0.999287    0.1
#
# [811 rows x 2 columns]

# %%
fs.combine_score(s1, s2, n=10)
# Out:
#         Score  Score_    Sum
# symbol
# SND     49.30   47.90  97.20
# GECC    45.60   49.80  95.40
# TNK     49.00   45.80  94.80
# STNG    44.75   46.75  91.50
# PVL     44.90   45.55  90.45
# LIVE    48.80   40.90  89.70
# AEL     45.90   43.10  89.00
# TRMD    44.55   43.65  88.20
# JOB     49.65   38.20  87.85
# BMA     48.65   38.70  87.35

# %%
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
terms
# Out:
# Index(['2010Q4', '2011Q1', '2011Q2', '2011Q3', '2011Q4', '2012Q1', '2012Q2',
#        '2012Q3', '2012Q4', '2013Q1', '2013Q2', '2013Q3', '2013Q4', '2014Q1',
#        '2014Q2', '2014Q3', '2014Q4', '2015Q1', '2015Q2', '2015Q3', '2015Q4',
#        '2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2', '2017Q3',
#        '2017Q4', '2018Q1', '2018Q2', '2018Q3', '2018Q4', '2019Q1', '2019Q2',
#        '2019Q3', '2019Q4', '2020Q1', '2020Q2', '2020Q3', '2020Q4'],
#       dtype='object')

# %%
data = {}
for t in terms:
  data[t] = fs.fn_consolidated(otp=16482659151081211164, term=t)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK

# %%
for t in terms:
  data[t]['Market Cap'] = data[t]['Price_M3'] * data[t]['Shares']
  data[t]['PER'] = data[t]['Price_M3'] / data[t]['EPS']
  data[t]['PBR'] = data[t]['Price_M3'] / (data[t]['Shareholders Equity'] / data[t]['Shares'])
  data[t]['PSR'] = data[t]['Price_M3'] / (data[t]['Revenue'] / data[t]['Shares'])
  data[t]['PCR'] = data[t]['Price_M3'] / ((data[t]['Net Income'] + data[t]['Depreciation']) / data[t]['Shares'])

# %%
data['2020Q4'].sort_values(by='Market Cap', ascending=False).head()
# Out:
#           term   Revenue      COGS  Gross Profit     SG&A  Operating Income  \
# symbol
# AAPL    2020Q4  294239.0  179823.0      114416.0  20350.0           74253.0
# MSFT    2020Q4  153284.0   48510.0      104774.0  24693.0           60155.0
# AMZN    2020Q4  386064.0  233307.0      152757.0  87194.0           22899.0
# GOOGL   2020Q4  182527.0   84732.0       97795.0  28998.0           41224.0
# GOOG    2020Q4  182528.0   84732.0       97796.0  28998.0           41224.0
#
#         Net Income      EPS   EBITDA     EBIT  ...                  name  \
# symbol                                         ...
# AAPL       63930.0   3.7175  85508.0  74253.0  ...             Apple Inc
# MSFT       51310.0   6.7800  72183.0  60155.0  ...        Microsoft Corp
# AMZN       21331.0  42.3000  47654.0  22899.0  ...        Amazon.com Inc
# GOOGL      40269.0  59.2600  54921.0  41224.0  ...  Alphabet Inc Class A
# GOOG       40269.0  59.0200  54922.0  41224.0  ...  Alphabet Inc Class C
#
#             name_kr                  sector                        industry  \
# symbol
# AAPL             애플              Technology            Consumer Electronics
# MSFT        마이크로소프트              Technology         Software Infrastructure
# AMZN          아마존닷컴       Consumer Cyclical                 Internet Retail
# GOOGL   알파벳 Class A  Communication Services  Internet Content & Information
# GOOG    알파벳 Class C  Communication Services  Internet Content & Information
#
#         avg_volume    Market Cap        PER        PBR        PSR        PCR
# symbol
# AAPL     186217000  2.068610e+06  32.858104  31.236565   7.030374  27.641914
# MSFT      33185700  1.781242e+06  34.774336  13.677035  11.620537  28.122807
# AMZN       5822800  1.553228e+06  73.146099  16.629140   4.023240  33.343956
# GOOGL      2787070  1.404197e+06  34.804590   6.309748   7.693090  26.020024
# GOOG       2618030  1.398394e+06  35.049644   6.283674   7.661257  25.912498
#
# [5 rows x 43 columns]

# %%
s1 = {}
s2 = {}
s3 = {}
s4 = {}
s5 = {}

for t in terms:
  s1[t] = fs.fn_filter(data[t], by='Market Cap', floor=0, n=1000, asc=True)
  s2[t] = fs.fn_score(data[t], by='PER', method='relative', floor=1, asc=True)
  s3[t] = fs.fn_score(data[t], by='PBR', method='relative', floor=.1, asc=True)
  s4[t] = fs.fn_score(data[t], by='PSR', method='relative', floor=.1, asc=True)
  s5[t] = fs.fn_score(data[t], by='PCR', method='relative', floor=.1, asc=True)

# %%
s6 = {}
for t in terms:
  s6[t] = fs.combine_score(s2[t], s3[t], s4[t], s5[t])

# %%
s = {}
signal = {}
for t in terms:
  s[t] = fs.combine_signal(s6[t], s1[t], how='and', n=50)
  signal[t] = list(s[t].index)

# %%
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# CAGR: 11.05%
# Accumulated return: 185.55%
# Investment period: 10.0yrs
# Sharpe ratio: 0.57
# MDD: -51.92%

# %%
fs.draw_return(df)

# %%
df = fs.fn_single(otp=16482659151081211164, symbol='NKE', window='T')

# %%
df['Market Cap'] = df['Price'] * df['Shares']
df['EV'] = df['Market Cap'] + df['Long Term Debt'] + df['Current Debt'] - df['Cash & Equivalents']

# %%
df['EV/EBITDA'] = df['EV'] / df['EBITDA']

# %%
df['PER'] = df['Price'] / df['EPS']
fs.draw_chart(df, left='PER', right='EV/EBITDA')

# %%
df['EV/Sales'] = df['EV'] / df['Revenue']
df['PSR'] = df['Price'] / (df['Revenue']/df['Shares'])
fs.draw_chart(df, left='PSR', right='EV/Sales')

# %%
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data={}
for t in terms:
  data[t]=fs.fn_consolidated(otp=16482659151081211164, term=t)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK

# %%
for t in terms:
  data[t]['Market Cap'] = data[t]['Price_M3']*data[t]['Shares']
  data[t]['EV']=data[t]['Market Cap']+data[t]['Long Term Debt'] + data[t]['Current Debt'] - data[t]['Cash & Equivalents']

# %%
for t in terms:
  data[t]['EV/EBITDA']=data[t]['EV'] / data[t]['EBITDA']
  data[t].loc[(data[t]['EV'] <= 0) | (data[t]['EBITDA'] <= 0), 'EV/EBITDA'] = float('nan')

# %%
s={}
signal={}
for t in terms:
  s[t] = fs.fn_filter(data[t], by='EV/EBITDA', floor=0, n=30, asc=True)
  signal[t] = list(s[t].index)

# %%
df=fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# CAGR: 9.48%
# Accumulated return: 147.56%
# Investment period: 10.0yrs
# Sharpe ratio: 0.51
# MDD: -49.39%

# %%
fs.draw_return(df)

# %%
df = fs.fn_single(otp=16482659151081211164, symbol='FB', window='T')

# %%
df['NCAV']=df['Current Assets'] - df['Total Liabilities']
df['Market Cap']=df['Price']*df['Shares']
df['Safety Margin']=df['NCAV']-df['Market Cap']

# %%
fs.draw_chart(df, left='Price', right='Safety Margin')

# %%
df['PBR'] = df['Price'] / (df['Shareholders Equity'] / df['Shares'])
fs.draw_chart(df, left='PBR', right='Safety Margin')

# %%
terms = fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data = {}
for t in terms:
  data[t] = fs.fn_consolidated(otp=16482659151081211164, term=t, vol=10000)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK

# %%
for t in terms:
  data[t]['NCAV'] = data[t]['Current Assets'] - data[t]['Total Liabilities']
  data[t]['Market Cap'] = data[t]['Price_M3'] * data[t]['Shares']
  data[t]['Safety Margin'] = data[t]['NCAV'] - data[t]['Market Cap']

# %%
s = {}
signal = {}
for t in terms:
  s[t]=fs.fn_filter(data[t], by='Safety Margin', floor=0, n=30, asc=False)
  signal[t] = list(s[t].index)

# %%
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# CAGR: 22.80%
# Accumulated return: 680.85%
# Investment period: 10.0yrs
# Sharpe ratio: 2.48
# MDD: -30.07%

# %%
fs.draw_return(df)

# %%
for k, v in signal.items():
  print(k, len(v))
# Out:
# 2010Q4 0
# 2011Q1 21
# 2011Q2 30
# 2011Q3 30
# 2011Q4 21
# 2012Q1 30
# 2012Q2 30
# 2012Q3 30
# 2012Q4 26
# 2013Q1 23
# 2013Q2 15
# 2013Q3 18
# 2013Q4 15
# 2014Q1 20
# 2014Q2 23
# 2014Q3 26
# 2014Q4 22
# 2015Q1 20
# 2015Q2 28
# 2015Q3 30
# 2015Q4 27
# 2016Q1 30
# 2016Q2 19
# 2016Q3 30
# 2016Q4 20
# 2017Q1 30
# 2017Q2 29
# 2017Q3 21
# 2017Q4 30
# 2018Q1 26
# 2018Q2 27
# 2018Q3 30
# 2018Q4 30
# 2019Q1 30
# 2019Q2 30
# 2019Q3 30
# 2019Q4 30
# 2020Q1 30
# 2020Q2 30
# 2020Q3 30
# 2020Q4 30

# %%
df = fs.fn_single(otp=16482659151081211164 , symbol='AAPL', window='T')

# %%
df['PER'] = df['Price'] / df['EPS']
df['EPS Growth'] = (df['EPS'] - df['EPS'].shift(4)) / abs(df['EPS'].shift(4)) * 100
df['PEG'] = (df['Price']/df['EPS'])/df['EPS Growth']

# %%
df[['EPS', 'EPS Growth', 'PER', 'PEG']].tail(10)
# Out:
#             EPS  EPS Growth   PER    PEG
# 2019-09-30 2.98       -0.25 18.76 -74.84
# 2019-12-31 3.19        3.99 23.01   5.76
# 2020-03-31 3.22        7.34 19.76   2.69
# 2020-06-30 3.32       12.26 27.47   2.24
# 2020-09-30 3.30       10.47 35.12   3.35
# 2020-12-31 3.74       17.16 35.50   2.07
# 2021-03-31 4.50       39.94 27.13   0.68
# 2021-06-30 5.16       55.42 26.54   0.48
# 2021-09-30 5.67       71.95 24.96   0.35
# 2021-12-31 6.08       62.68 29.21   0.47

# %%
df = fs.fn_single(otp=16482659151081211164 , symbol='AMZN', window='T')
df['PER'] = df['Price'] / df['EPS']
df['EPS Growth'] = (df['EPS']-df['EPS'].shift(4))/abs(df['EPS'].shift(4))*100
df['PEG'] = (df['Price']/df['EPS'])/df['EPS Growth']
df[['EPS', 'EPS Growth', 'PER', 'PEG']].tail(10)
# Out:
#              EPS  EPS Growth    PER   PEG
# 2019-09-30 23.05       25.75  75.31  2.92
# 2019-12-31 23.45       13.50  78.80  5.84
# 2020-03-31 21.30      -13.20  91.54 -6.93
# 2020-06-30 26.48        7.42 104.19 14.03
# 2020-09-30 34.80       50.98  90.48  1.77
# 2020-12-31 42.30       80.38  77.00  0.96
# 2021-03-31 53.01      148.87  58.37  0.39
# 2021-06-30 57.64      117.67  59.68  0.51
# 2021-09-30 51.14       46.95  64.24  1.37
# 2021-12-31 64.82       53.24  51.44  0.97

# %%
df=fs.fn_single(otp=16482659151081211164 , symbol='BABA', window='T')

# %%
fs.draw_chart(df, left=['Total Assets', 'Shareholders Equity'], right='Net Income')

# %%
df['Total Assets'].tail()
# Out:
# 2020-12-31   250,179,741,935.48
# 2021-03-31   258,006,563,706.56
# 2021-06-30   265,318,404,118.40
# 2021-09-30   266,867,008,985.88
# 2021-12-31   276,115,000,000.00
# Name: Total Assets, dtype: float64

# %%
df['Shifted Total Assets'] = df['Total Assets'].shift(4)

# %%
df['Avg Assets'] = (df['Total Assets'] + df['Total Assets'].shift(4)) / 2

# %%
df[['Total Assets', 'Shifted Total Assets', 'Avg Assets']]
# Out:
#                  Total Assets  Shifted Total Assets         Avg Assets
# 2014-09-30  37,853,000,000.00                   NaN                NaN
# 2014-12-31  43,515,000,000.00                   NaN                NaN
# 2015-03-31  41,206,000,000.00                   NaN                NaN
# 2015-06-30  45,494,000,000.00                   NaN                NaN
# 2015-09-30  51,570,000,000.00     37,853,000,000.00  44,711,500,000.00
# 2015-12-31  56,296,000,000.00     43,515,000,000.00  49,905,500,000.00
# 2016-03-31  56,521,000,000.00     41,206,000,000.00  48,863,500,000.00
# 2016-06-30  61,688,000,000.00     45,494,000,000.00  53,591,000,000.00
# 2016-09-30  68,441,000,000.00     51,570,000,000.00  60,005,500,000.00
# 2016-12-31  70,699,000,000.00     56,296,000,000.00  63,497,500,000.00
# 2017-03-31  73,630,000,000.00     56,521,000,000.00  65,075,500,000.00
# 2017-06-30  80,202,000,000.00     61,688,000,000.00  70,945,000,000.00
# 2017-09-30  86,998,000,000.00     68,441,000,000.00  77,719,500,000.00
# 2017-12-31 109,345,000,000.00     70,699,000,000.00  90,022,000,000.00
# 2018-03-31 114,326,000,000.00     73,630,000,000.00  93,978,000,000.00
# 2018-06-30 120,394,000,000.00     80,202,000,000.00 100,298,000,000.00
# 2018-09-30 120,088,000,000.00     86,998,000,000.00 103,543,000,000.00
# 2018-12-31 133,509,000,000.00    109,345,000,000.00 121,427,000,000.00
# 2019-03-31 143,801,000,000.00    114,326,000,000.00 129,063,500,000.00
# 2019-06-30 148,413,000,000.00    120,394,000,000.00 134,403,500,000.00
# 2019-09-30 162,231,000,000.00    120,088,000,000.00 141,159,500,000.00
# 2019-12-31 189,534,000,000.00    133,509,000,000.00 161,521,500,000.00
# 2020-03-31 185,429,000,000.00    143,801,000,000.00 164,615,000,000.00
# 2020-06-30 193,794,000,000.00    148,413,000,000.00 171,103,500,000.00
# 2020-09-30 211,150,000,000.00    162,231,000,000.00 186,690,500,000.00
# 2020-12-31 250,179,741,935.48    189,534,000,000.00 219,856,870,967.74
# 2021-03-31 258,006,563,706.56    185,429,000,000.00 221,717,781,853.28
# 2021-06-30 265,318,404,118.40    193,794,000,000.00 229,556,202,059.20
# 2021-09-30 266,867,008,985.88    211,150,000,000.00 239,008,504,492.94
# 2021-12-31 276,115,000,000.00    250,179,741,935.48 263,147,370,967.74

# %%
df['Avg Assets'] = (df['Total Assets']+ df['Total Assets'].shift(4))/2

# %%
df['ROA'] = df['Net Income'] / df['Avg Assets']
df[['ROA', 'Net Income', 'Avg Assets']].tail()
# Out:
#             ROA        Net Income         Avg Assets
# 2020-12-31 0.11 23,282,129,032.26 219,856,870,967.74
# 2021-03-31 0.10 22,116,856,187.99 221,717,781,853.28
# 2021-06-30 0.10 22,367,085,274.21 229,556,202,059.20
# 2021-09-30 0.08 18,958,454,978.96 239,008,504,492.94
# 2021-12-31 0.04 10,161,479,792.86 263,147,370,967.74

# %%
fs.draw_chart(df, left='ROA', right='Price')

# %%
df['Avg Equity'] = (df['Shareholders Equity']+df['Shareholders Equity'].shift(4)) / 2
df['ROE'] = df['Net Income'] / df['Avg Equity']
df[['ROE', 'Net Income', 'Avg Equity']].tail()
# Out:
#             ROE        Net Income         Avg Equity
# 2020-12-31 0.17 23,282,129,032.26 133,398,629,032.26
# 2021-03-31 0.17 22,116,856,187.99 133,025,074,002.57
# 2021-06-30 0.16 22,367,085,274.21 140,605,113,899.61
# 2021-09-30 0.13 18,958,454,978.96 146,117,050,706.03
# 2021-12-31 0.07 10,161,479,792.86 148,084,885,442.51

# %%
fs.draw_chart(df, left='ROE', right='Price')

# %%
fs.draw_chart(df, left=['ROA', 'ROE'], right='Price')

# %%
terms=fs.set_terms(trade_start='2011Q1', trade_end='2021Q1')
data={}
for t in terms:
  data[t] = fs.fn_consolidated(otp=16482659151081211164 , term=t)
# Out:
# 2010Q4...OK
# 2011Q1...OK
# 2011Q2...OK
# 2011Q3...OK
# 2011Q4...OK
# 2012Q1...OK
# 2012Q2...OK
# 2012Q3...OK
# 2012Q4...OK
# 2013Q1...OK
# 2013Q2...OK
# 2013Q3...OK
# 2013Q4...OK
# 2014Q1...OK
# 2014Q2...OK
# 2014Q3...OK
# 2014Q4...OK
# 2015Q1...OK
# 2015Q2...OK
# 2015Q3...OK
# 2015Q4...OK
# 2016Q1...OK
# 2016Q2...OK
# 2016Q3...OK
# 2016Q4...OK
# 2017Q1...OK
# 2017Q2...OK
# 2017Q3...OK
# 2017Q4...OK
# 2018Q1...OK
# 2018Q2...OK
# 2018Q3...OK
# 2018Q4...OK
# 2019Q1...OK
# 2019Q2...OK
# 2019Q3...OK
# 2019Q4...OK
# 2020Q1...OK
# 2020Q2...OK
# 2020Q3...OK
# 2020Q4...OK

# %%
for t in terms:
  prev_t = fs.quarters_before(terms, t, 4)
  data[t]['Avg Assets'] = (data[t]['Total Assets'] + data[prev_t]['Total Assets'])/2
  data[t]['ROA'] = data[t]['Net Income'] / data[t]['Avg Assets']
  data[t].loc[(data[t]['Net Income']<0) | (data[t]['Avg Assets']< 0) | (data[t]['Total Assets'] < 0), 'ROA'] = float('nan')

# %%
s = {}
signal = {}
for t in terms:
  s[t] = fs.fn_filter(data[t], by='ROA', floor=0, n=30, asc=False)
  signal[t] = list(s[t].index)

# %%
df = fs.backtest(signal = signal, data=data, m=3, cost=.001)
# Out:
# CAGR: 5.23%
# Accumulated return: 66.51%
# Investment period: 10.0yrs
# Sharpe ratio: 0.32
# MDD: -33.96%

# %%
fs.draw_return(df)

# %%
df = fs.fn_single(otp=16482659151081211164 , symbol='JPM', window='T')

# %%
df['BPS'] = df['Shareholders Equity'] / df['Shares']
df['ROE'] = df['Net Income'] / df['Shareholders Equity']

# %%
df['ROE3AVG'] = df['ROE'].rolling(12).mean()

# %%
df['RIM'] = df['BPS'] * df['ROE3AVG'] / .1

# %%
fs.draw_chart(df, right=['Price', 'RIM'])

# %%
df['RIM6'] = df['BPS'] * df['ROE3AVG'] / .06
df['RIM7'] = df['BPS'] * df['ROE3AVG'] / .07
df['RIM8'] = df['BPS'] * df['ROE3AVG'] / .08
fs.draw_chart(df, right=['Price', 'RIM', 'RIM6', 'RIM7', 'RIM8'])

# %%
for t in terms:
  t_1 = fs.quarters_before(terms, t, 4)
  t_2 = fs.quarters_before(terms, t, 8)
  data[t]['BPS'] = data[t]['Shareholders Equity'] / data[t]['Shares']
  data[t]['Avg Equity'] = (data[t]['Shareholders Equity'] + data[t_1]['Shareholders Equity'])/2
  data[t]['ROE'] = data[t]['Net Income'] / data[t]['Avg Equity']
  data[t].loc[(data[t]['Net Income']<0) | (data[t]['Avg Equity']< 0) | (data[t]['Shareholders Equity'] < 0), 'ROE'] = float('nan')
  data[t]['Avg ROE'] = (data[t]['ROE'] + data[t_1]['ROE'] +data[t_2]['ROE'])/3
  data[t]['RIM'] = data[t]['BPS'] * data[t]['Avg ROE']/.1
  data[t]['P/RIM'] = data[t]['Price_M3'] / data[t]['RIM']

# %%
s={}
signal = {}
for t in terms:
  s[t] = fs.fn_filter(data[t], by='P/RIM', floor=0, cap=1, n=30, asc=True)
  signal[t] = list(s[t].index)

# %%
df = fs.backtest(signal=signal, data=data, m=3, cost=.001)
# Out:
# CAGR: 6.97%
# Accumulated return: 96.32%
# Investment period: 10.0yrs
# Sharpe ratio: 0.35
# MDD: -46.61%

# %%
fs.draw_return(df)
